# %%
# Importing dependencies required for our analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import scipy.stats as st
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
# Read csv file
crime_df = pd.read_csv("Crime Stats Cleaned v2.csv")

# %%
# Display data
crime_df.head()
# Out:
#      Year          County  Month County Pop County Pop ('000s) Violent_sum  \
# 0  2019.0  Alameda County    1.0    1668412               1668          50
# 1  2019.0  Alameda County    2.0    1668412               1668          49
# 2  2019.0  Alameda County    3.0    1668412               1668          52
# 3  2019.0  Alameda County    4.0    1668412               1668          60
# 4  2019.0  Alameda County    5.0    1668412               1668          62
#
#   Homicide_sum ForRape_sum Robbery_sum AggAssault_sum Property_sum  \
# 0            0           1          19             30          195
# 1            1           2          19             27          187
# 2            1           1          20             30          153
# 3            0           3          15             42          174
# 4            0           1          23             38          180
#
#   Burglary_sum VehicleTheft_sum LTtotal_sum
# 0           23               48         124
# 1           34               47         106
# 2           20               23         110
# 3           41               34          99
# 4           31               38         111

# %%
# Check data types
crime_df.dtypes
# Out:
# Year                  float64
# County                 object
# Month                 float64
# County Pop             object
# County Pop ('000s)     object
# Violent_sum            object
# Homicide_sum           object
# ForRape_sum            object
# Robbery_sum            object
# AggAssault_sum         object
# Property_sum           object
# Burglary_sum           object
# VehicleTheft_sum       object
# LTtotal_sum            object
# dtype: object

# %%
# Rename columns 
crime_df.rename(columns={'County Pop':'Country_Pop',"County Pop ('000s)":"County_Pop_('000s)",'LTtotal_sum':'LarcenyTheft_sum'} , inplace = True)
crime_df
# Out:
#          Year          County  Month Country_Pop County_Pop_('000s)  \
# 0      2019.0  Alameda County    1.0     1668412               1668
# 1      2019.0  Alameda County    2.0     1668412               1668
# 2      2019.0  Alameda County    3.0     1668412               1668
# 3      2019.0  Alameda County    4.0     1668412               1668
# 4      2019.0  Alameda County    5.0     1668412               1668
# ...       ...             ...    ...         ...                ...
# 34582  2022.0     Yuba County    9.0       84310                 84
# 34583  2022.0     Yuba County   10.0       84310                 84
# 34584  2022.0     Yuba County   11.0       84310                 84
# 34585  2022.0     Yuba County   12.0       84310                 84
# 34586     NaN             NaN    NaN           .                  .
#
#       Violent_sum Homicide_sum ForRape_sum Robbery_sum AggAssault_sum  \
# 0              50            0           1          19             30
# 1              49            1           2          19             27
# 2              52            1           1          20             30
# 3              60            0           3          15             42
# 4              62            0           1          23             38
# ...           ...          ...         ...         ...            ...
# 34582           0            0           0           0              0
# 34583           0            0           0           0              0
# 34584           0            0           0           0              0
# 34585           0            0           0           0              0
# 34586         NaN          NaN         NaN         NaN            NaN
#
#       Property_sum Burglary_sum VehicleTheft_sum LarcenyTheft_sum
# 0              195           23               48              124
# 1              187           34               47              106
# 2              153           20               23              110
# 3              174           41               34               99
# 4              180           31               38              111
# ...            ...          ...              ...              ...
# 34582            0            0                0                0
# 34583            2            0                0                2
# 34584            0            0                0                0
# 34585            1            0                0                1
# 34586          NaN          NaN              NaN              NaN
#
# [34587 rows x 14 columns]

# %%
# Remove leading and trailing white spaces, replace empty values with nan then drop nan values 
# convert data types to int and string

crime_df_cleaned = crime_df.dropna()
for c in crime_df.columns:
    if c!="County":
        if crime_df[c].dtype == "object":
            crime_df_cleaned[c] = crime_df_cleaned[c].str.strip()
            crime_df_cleaned[c].replace('', np.nan, inplace=True)
        #Removed all the nan rows    
        crime_df_cleaned = crime_df_cleaned.dropna()
        #convert to int
        crime_df_cleaned[c] = crime_df_cleaned[c].astype("int64")

crime_df_cleaned["County"] = crime_df_cleaned["County"].astype('string')
crime_df_cleaned
# Out:
#        Year          County  Month  Country_Pop  County_Pop_('000s)  \
# 0      2019  Alameda County      1      1668412                1668
# 1      2019  Alameda County      2      1668412                1668
# 2      2019  Alameda County      3      1668412                1668
# 3      2019  Alameda County      4      1668412                1668
# 4      2019  Alameda County      5      1668412                1668
# ...     ...             ...    ...          ...                 ...
# 34581  2022     Yuba County      8        84310                  84
# 34582  2022     Yuba County      9        84310                  84
# 34583  2022     Yuba County     10        84310                  84
# 34584  2022     Yuba County     11        84310                  84
# 34585  2022     Yuba County     12        84310                  84
#
#        Violent_sum  Homicide_sum  ForRape_sum  Robbery_sum  AggAssault_sum  \
# 0               50             0            1           19              30
# 1               49             1            2           19              27
# 2               52             1            1           20              30
# 3               60             0            3           15              42
# 4               62             0            1           23              38
# ...            ...           ...          ...          ...             ...
# 34581            0             0            0            0               0
# 34582            0             0            0            0               0
# 34583            0             0            0            0               0
# 34584            0             0            0            0               0
# 34585            0             0            0            0               0
#
#        Property_sum  Burglary_sum  VehicleTheft_sum  LarcenyTheft_sum
# 0               195            23                48               124
# 1               187            34                47               106
# 2               153            20                23               110
# 3               174            41                34                99
# 4               180            31                38               111
# ...             ...           ...               ...               ...
# 34581             0             0                 0                 0
# 34582             0             0                 0                 0
# 34583             2             0                 0                 2
# 34584             0             0                 0                 0
# 34585             1             0                 0                 1
#
# [34585 rows x 14 columns]

# %%
#check data types 
crime_df_cleaned.dtypes
# Out:
# Year                   int64
# County                string
# Month                  int64
# Country_Pop            int64
# County_Pop_('000s)     int64
# Violent_sum            int64
# Homicide_sum           int64
# ForRape_sum            int64
# Robbery_sum            int64
# AggAssault_sum         int64
# Property_sum           int64
# Burglary_sum           int64
# VehicleTheft_sum       int64
# LarcenyTheft_sum       int64
# dtype: object

# %%
#Identify unique values on each crime :'Violent_sum','Homicide_sum','ForRape_sum','Robbery_sum','AggAssault_sum','Property_sum','Burglary_sum','VehicleTheft_sum','LarcenyTheft_sum'
unique_v = crime_df_cleaned["Violent_sum"].unique()
print('Violent' ,unique_v)
# unique_h = crime_df_cleaned["Homicide_sum"].unique()
# print('Homicide',unique_h)
# unique_r = crime_df_cleaned["ForRape_sum"].unique()
# print('Rape',unique_r)
# unique_rob = crime_df_cleaned["Robbery_sum"].unique()
# print('Robbery',unique_rob)
# unique_agg = crime_df_cleaned["AggAssault_sum"].unique()
# print('AggAssault',unique_agg)
# unique_pro = crime_df_cleaned["Property_sum"].unique()
# print('Property',unique_pro)
# unique_bur = crime_df_cleaned["Burglary_sum"].unique()
# print('Buglary',unique_bur)
# unique_v = crime_df_cleaned["VehicleTheft_sum"].unique()
# print('Vehicle',unique_v)
# unique_larceny = crime_df_cleaned["LarcenyTheft_sum"].unique()
# print('Larceny',unique_rob)
# 34582  2022     Yuba County      9        84310                  84
# 34583  2022     Yuba County     10        84310                  84
# 34584  2022     Yuba County     11        84310                  84
# 34585  2022     Yuba County     12        84310                  84
#
#        Violent_sum  Homicide_sum  ForRape_sum  Robbery_sum  AggAssault_sum  \
# 0               50             0            1           19              30
# 1               49             1            2           19              27
# 2               52             1            1           20              30
# 3               60             0            3           15              42
# 4               62             0            1           23              38
# ...            ...           ...          ...          ...             ...
# 34581            0             0            0            0               0
# 34582            0             0            0            0               0
# 34583            0             0            0            0               0
# 34584            0             0            0            0               0
# 34585            0             0            0            0               0
#
#        Property_sum  Burglary_sum  VehicleTheft_sum  LarcenyTheft_sum
# 0               195            23                48               124
# 1               187            34                47               106
# 2               153            20                23               110
# 3               174            41                34                99
# 4               180            31                38               111
# ...             ...           ...               ...               ...
# 34581             0             0                 0                 0
# 34582             0             0                 0                 0
# 34583             2             0                 0                 2
# 34584             0             0                 0                 0
# 34585             1             0                 0                 1
#
# [34478 rows x 14 columns]

# %%
#crime_df_cleaned.to_csv("crime_df_cleaned_lastV.csv")
# newdf = pd.read_csv('crime_df_cleaned_lastV.csv')

# %%
newdf = crime_df_cleaned

# %%
newdf.columns
# Out:
# Index(['Year', 'County', 'Month', 'Country_Pop', 'County_Pop_('000s)',
#        'Violent_sum', 'Homicide_sum', 'ForRape_sum', 'Robbery_sum',
#        'AggAssault_sum', 'Property_sum', 'Burglary_sum', 'VehicleTheft_sum',
#        'LarcenyTheft_sum'],
#       dtype='object')

# %%
newdf.head(5)
# Out:
#    Year          County  Month  Country_Pop  County_Pop_('000s)  Violent_sum  \
# 0  2019  Alameda County      1      1668412                1668           50
# 1  2019  Alameda County      2      1668412                1668           49
# 2  2019  Alameda County      3      1668412                1668           52
# 3  2019  Alameda County      4      1668412                1668           60
# 4  2019  Alameda County      5      1668412                1668           62
#
#    Homicide_sum  ForRape_sum  Robbery_sum  AggAssault_sum  Property_sum  \
# 0             0            1           19              30           195
# 1             1            2           19              27           187
# 2             1            1           20              30           153
# 3             0            3           15              42           174
# 4             0            1           23              38           180
#
#    Burglary_sum  VehicleTheft_sum  LarcenyTheft_sum
# 0            23                48               124
# 1            34                47               106
# 2            20                23               110
# 3            41                34                99
# 4            31                38               111

# %%
newdf = newdf.rename(columns = {'Year': 'year',
                                'County': 'county',
                                'Month': 'month',
                                'Country_Pop': 'county_pop',
                                "County_Pop_('000s)": "county_pop_('000s')",
                                'Violent_sum': 'violent',
                                'Homicide_sum': 'homicide',
                                'ForRape_sum': 'rape',
                                'Robbery_sum': 'robbery',
                                'AggAssault_sum': 'agg_assault',
                                'Property_sum': 'property',
                                'Burglary_sum': 'burglary',
                                'VehicleTheft_sum': 'vehicle_theft',
                                'LarcenyTheft_sum': 'larceny_theft'})
newdf.columns
# Out:
# Index(['year', 'county', 'month', 'county_pop', 'county_pop_('000s')',
#        'violent', 'homicide', 'rape', 'robbery', 'agg_assault', 'property',
#        'burglary', 'vehicle_theft', 'larceny_theft'],
#       dtype='object')

# %%
newdf.drop("county_pop_('000s')", axis=1, inplace=True)
newdf
# Out:
#        year          county  month  county_pop  violent  homicide  rape  \
# 0      2019  Alameda County      1     1668412       50         0     1
# 1      2019  Alameda County      2     1668412       49         1     2
# 2      2019  Alameda County      3     1668412       52         1     1
# 3      2019  Alameda County      4     1668412       60         0     3
# 4      2019  Alameda County      5     1668412       62         0     1
# ...     ...             ...    ...         ...      ...       ...   ...
# 34581  2022     Yuba County      8       84310        0         0     0
# 34582  2022     Yuba County      9       84310        0         0     0
# 34583  2022     Yuba County     10       84310        0         0     0
# 34584  2022     Yuba County     11       84310        0         0     0
# 34585  2022     Yuba County     12       84310        0         0     0
#
#        robbery  agg_assault  property  burglary  vehicle_theft  larceny_theft
# 0           19           30       195        23             48            124
# 1           19           27       187        34             47            106
# 2           20           30       153        20             23            110
# 3           15           42       174        41             34             99
# 4           23           38       180        31             38            111
# ...        ...          ...       ...       ...            ...            ...
# 34581        0            0         0         0              0              0
# 34582        0            0         0         0              0              0
# 34583        0            0         2         0              0              2
# 34584        0            0         0         0              0              0
# 34585        0            0         1         0              0              1
#
# [34478 rows x 13 columns]

# %%
newdf['month'] = newdf['month'].replace({1: 'January',
                                        2: 'February',
                                        3: 'March',
                                        4: 'April',
                                        5: 'May',
                                        6: 'June',
                                        7: 'July',
                                        8: 'August',
                                        9: 'September',
                                        10: 'October',
                                        11: 'November',
                                        12: 'December'})
newdf.head(5)
# Out:
#    year          county     month  county_pop  violent  homicide  rape  \
# 0  2019  Alameda County   January     1668412       50         0     1
# 1  2019  Alameda County  February     1668412       49         1     2
# 2  2019  Alameda County     March     1668412       52         1     1
# 3  2019  Alameda County     April     1668412       60         0     3
# 4  2019  Alameda County       May     1668412       62         0     1
#
#    robbery  agg_assault  property  burglary  vehicle_theft  larceny_theft
# 0       19           30       195        23             48            124
# 1       19           27       187        34             47            106
# 2       20           30       153        20             23            110
# 3       15           42       174        41             34             99
# 4       23           38       180        31             38            111

# %%
df = newdf.groupby(['year', 'county']).sum()
df
# Out:
#                        county_pop  violent  homicide  rape  robbery  \
# year county
# 2019 Alameda County     417103000     9706        96   704     4900
#      Alpine County          26712       13         0     2        0
#      Amador County        2818203      108         1     9        8
#      Butte County        26247120     1024         7   180      167
#      Calaveras County     2767140      145         1    34        9
# ...                           ...      ...       ...   ...      ...
# 2022 Tulare County       74496864     2087        44   184      383
#      Tuolumne County      1963116      375         0    70       14
#      Ventura County     177344865     1645        18   175      368
#      Yolo County         21323040      596         4    82       99
#      Yuba County          4046880      279         5    33       40
#
#                        agg_assault  property  burglary  vehicle_theft  \
# year county
# 2019 Alameda County           4006     66349      6493          10216
#      Alpine County              11        32        13              4
#      Amador County              90       638       165             37
#      Butte County              670      5322      1111            868
#      Calaveras County          101       838       297             69
# ...                            ...       ...       ...            ...
# 2022 Tulare County            1476      9876      1512           2136
#      Tuolumne County           291       728       198             61
#      Ventura County           1084     11124      1619           1306
#      Yolo County               411      5215       639            602
#      Yuba County               201      1227       302            131
#
#                        larceny_theft
# year county
# 2019 Alameda County            49640
#      Alpine County                15
#      Amador County               436
#      Butte County               3343
#      Calaveras County            472
# ...                              ...
# 2022 Tulare County              6228
#      Tuolumne County             469
#      Ventura County             8199
#      Yolo County                3974
#      Yuba County                 794
#
# [232 rows x 10 columns]

# %%
# Reset index
df.reset_index(inplace = True)

# %%
# Convert a crime column into a t list and iderate through in a list of comprehension 
crime_column = list(df.columns)
crime_column_list = [i for i in crime_column if i not in ('year', 'county', 'month', 'county_pop')]
# Filter by year 2019
y_2019 = df.loc[df['year'] == 2019]
y_2019.set_index('county', inplace=True)
# Fileter by year 2020
y_2020 = df.loc[df['year'] == 2020]
y_2020.set_index('county', inplace=True)

# Get all the counties population summary
summary_df = y_2019['county_pop'].to_frame()
summary_df.reset_index(inplace=True)

# Display(summary_df)
for c in crime_column_list:
    df_crimes = (y_2020[c]-y_2019[c])/y_2019[c]
    df_crimes.sort_values(ascending=False)
    df_crimes = df_crimes.to_frame()
    df_crimes.reset_index(inplace=True)
    #print(df_crimes.dropna().sort_values(ascending=False).head(9))
    # Merge Data Frames and comprare between 2019 and 2020
    summary_df =  summary_df.merge(df_crimes)
summary_df
# Out:
#                     county   county_pop   violent  homicide      rape  \
# 0           Alameda County    417103000 -0.006285  0.489583 -0.028409
# 1            Alpine County        26712  0.461538       NaN -1.000000
# 2            Amador County      2818203  0.444444  1.000000  0.111111
# 3             Butte County     26247120  0.043945  0.714286 -0.288889
# 4         Calaveras County      2767140  0.089655 -1.000000 -0.441176
# 5            Colusa County      1288440  0.051724       inf -0.400000
# 6      Contra Costa County    344712017 -0.063457 -0.188679 -0.115265
# 7         Del Norte County      1004508  0.825688  0.000000  3.153846
# 8         El Dorado County     11390363  0.137615 -1.000000  0.137931
# 9            Fresno County    261435914  0.253958  0.709091  0.131086
# 10            Glenn County      1365360  0.670330  0.000000  0.333333
# 11         Humboldt County     16300680  0.006390  0.500000 -0.075758
# 12         Imperial County     17322144 -0.011885  0.000000  0.142857
# 13             Inyo County       863664  0.351064  0.000000 -0.500000
# 14             Kern County    171689518  0.117383  0.380952 -0.272527
# 15            Kings County     14661792  0.023778  1.750000 -0.098592
# 16             Lake County      3094224  0.011527 -0.800000 -0.302326
# 17           Lassen County      1442618 -0.219331       NaN -0.750000
# 18      Los Angeles County  12174108032 -0.030925  0.332677 -0.099498
# 19           Madera County      9403020 -0.303614  2.000000 -0.102941
# 20            Marin County     43526280  0.207364  0.000000  0.181818
# 21         Mariposa County       410808 -0.227848       NaN  0.500000
# 22        Mendocino County      6259104  0.104167  1.000000 -0.377778
# 23           Merced County     36579048  0.076316  0.833333  0.048780
# 24            Modoc County       425568 -0.139535       inf  0.000000
# 25             Mono County       520200 -0.373134       inf -0.611111
# 26         Monterey County     93610080  0.032798 -0.066667  0.258993
# 27             Napa County     14593868 -0.262654  0.000000 -0.285714
# 28           Nevada County      7174656 -0.058824  0.666667  0.062500
# 29           Orange County   1582254649  0.079758  0.035088 -0.128492
# 30           Placer County     37897210  0.079526  0.000000 -0.178947
# 31           Plumas County       685872  0.242188  0.000000  1.000000
# 32        Riverside County   1035538980 -0.035681  0.305085 -0.018145
# 33       Sacramento County    316538640  0.081153  0.282051  0.061425
# Calaveras County  2019     2767140      145         1    34        9
#
#                   agg_assault  property  burglary  vehicle_theft  \
# county
# Alameda County           4006     66349      6493          10216
# Alpine County              11        32        13              4
# Amador County              90       638       165             37
# Butte County              670      5322      1111            868
# Calaveras County          101       838       297             69
#
#                   larceny_theft
# county
# Alameda County            49640
# Alpine County                15
# Amador County               436
# Butte County               3343
# Calaveras County            472

# %%
# Filter data by 2020
y_2020 = df.loc[df['year'] == 2020]
y_2020.set_index('county', inplace=True)
y_2020.head(5)
# Out:
#                   year  county_pop  violent  homicide  rape  robbery  \
# county
# Alameda County    2020   438853272     9645       143   684     4149
# Alpine County     2020       26856       19         0     0        0
# Amador County     2020     2885976      156         2    10       14
# Butte County      2020    24252816     1069        12   128      143
# Calaveras County  2020     2778480      158         0    19        7
#
#                   agg_assault  property  burglary  vehicle_theft  \
# county
# Alameda County           4669     58293      7034          14456
# Alpine County              19        14         4              0
# Amador County             130       582       136             45
# Butte County              786      4345       836            669
# Calaveras County          132       766       244             72
#
#                   larceny_theft
# county
# Alameda County            36803
# Alpine County                10
# Amador County               401
# Butte County               2840
# Calaveras County            450

# %%
# Filter data by 2021
y_2021 = df.loc[df['year'] == 2021]
y_2021.set_index('county', inplace=True)
y_2021.head(5)
# Out:
#                   year  county_pop  violent  homicide  rape  robbery  \
# county
# Alameda County    2021   430685294    10510       146   671     4568
# Alpine County     2021       27170       19         0     2        0
# Amador County     2021     2921224      135         4     9       13
# Butte County      2021    22268520     1110        13   151      120
# Calaveras County  2021     2773140      185         2    35        4
#
#                   agg_assault  property  burglary  vehicle_theft  \
# county
# Alameda County           5125     61001      5907          15496
# Alpine County              17        23         8              1
# Amador County             109       716       133             77
# Butte County              826      4785       818            916
# Calaveras County          144       677       183            109
#
#                   larceny_theft
# county
# Alameda County            39598
# Alpine County                14
# Amador County               506
# Butte County               3051
# Calaveras County            385

# %%
# Filter data by 2022
y_2022 = df.loc[df['year'] == 2021]
y_2022.set_index('county', inplace=True)
y_2022.head(5)
# Out:
#                   year  county_pop  violent  homicide  rape  robbery  \
# county
# Alameda County    2021   430685294    10510       146   671     4568
# Alpine County     2021       27170       19         0     2        0
# Amador County     2021     2921224      135         4     9       13
# Butte County      2021    22268520     1110        13   151      120
# Calaveras County  2021     2773140      185         2    35        4
#
#                   agg_assault  property  burglary  vehicle_theft  \
# county
# Alameda County           5125     61001      5907          15496
# Alpine County              17        23         8              1
# Amador County             109       716       133             77
# Butte County              826      4785       818            916
# Calaveras County          144       677       183            109
#
#                   larceny_theft
# county
# Alameda County            39598
# Alpine County                14
# Amador County               506
# Butte County               3051
# Calaveras County            385

# %%
# Compare property crime between 2019 and 2020
df_property = (y_2020['property']-y_2019['property'])/y_2019['property']
df_property.sort_values(ascending=False)
# Out:
# county
# Shasta County             0.421467
# San Benito County         0.213983
# Santa Barbara County      0.208020
# Modoc County              0.181818
# Mendocino County          0.125100
# Mariposa County           0.098901
# Napa County               0.066605
# Fresno County             0.060875
# Siskiyou County           0.052381
# Sutter County             0.044358
# Ventura County            0.035539
# Orange County             0.032197
# Kings County              0.016221
# El Dorado County          0.013856
# Monterey County          -0.000905
# Yuba County              -0.001627
# Imperial County          -0.026467
# Marin County             -0.031233
# Yolo County              -0.032812
# Placer County            -0.036139
# San Mateo County         -0.041052
# Sonoma County            -0.041268
# Los Angeles County       -0.045629
# Colusa County            -0.046110
# Lake County              -0.050489
# Kern County              -0.056942
# Plumas County            -0.063694
# Calaveras County         -0.085919
# Santa Clara County       -0.086733
# Amador County            -0.087774
# Riverside County         -0.089677
# Sacramento County        -0.093916
# San Luis Obispo County   -0.098377
# Tuolumne County          -0.099628
# San Diego County         -0.103653
# Tulare County            -0.115294
# Humboldt County          -0.117677
# Alameda County           -0.121419
# Lassen County            -0.121588
# Santa Cruz County        -0.137901
# Mono County              -0.139037
# Nevada County            -0.141898
# Merced County            -0.147579
# Glenn County             -0.152091
# Trinity County           -0.164557
# San Bernardino County    -0.165748
# San Joaquin County       -0.168340
# Contra Costa County      -0.168773
# Inyo County              -0.183206
# Butte County             -0.183578
# Tehama County            -0.202711
# Solano County            -0.204620
# Del Norte County         -0.207711
# Madera County            -0.208318
# San Francisco County     -0.212129
# Stanislaus County        -0.240367
# Sierra County            -0.451613
# Alpine County            -0.562500
# Name: property, dtype: float64

# %%
# Compare violenr crim between 2020 and 2019
df_violent = (y_2020['violent']-y_2019['violent'])/y_2019['violent']
df_violent.sort_values(ascending=False)
df_violent
# Out:
# county
# Alameda County           -0.006285
# Alpine County             0.461538
# Amador County             0.444444
# Butte County              0.043945
# Calaveras County          0.089655
# Colusa County             0.051724
# Contra Costa County      -0.063457
# Del Norte County          0.825688
# El Dorado County          0.137615
# Fresno County             0.253958
# Glenn County              0.670330
# Humboldt County           0.006390
# Imperial County          -0.011885
# Inyo County               0.351064
# Kern County               0.117383
# Kings County              0.023778
# Lake County               0.011527
# Lassen County            -0.219331
# Los Angeles County       -0.030925
# Madera County            -0.303614
# Marin County              0.207364
# Mariposa County          -0.227848
# Mendocino County          0.104167
# Merced County             0.076316
# Modoc County             -0.139535
# Mono County              -0.373134
# Monterey County           0.032798
# Napa County              -0.262654
# Nevada County            -0.058824
# Orange County             0.079758
# Placer County             0.079526
# Plumas County             0.242188
# Riverside County         -0.035681
# Sacramento County         0.081153
# San Benito County         0.115646
# San Bernardino County     0.048707
# San Diego County          0.009305
# San Francisco County     -0.192055
# San Joaquin County       -0.073085
# San Luis Obispo County    0.299363
# San Mateo County         -0.045182
# Santa Barbara County      0.192937
# Santa Clara County       -0.035057
# Santa Cruz County        -0.151899
# Shasta County             0.568218
# Sierra County             3.000000
# Siskiyou County           0.278409
# Solano County             0.106433
# Sonoma County             0.105447
# Stanislaus County        -0.029230
# Sutter County             0.057823
# Tehama County             0.355469
# Trinity County            0.344262
# Tulare County             0.004137
# Tuolumne County           0.251282
# Ventura County           -0.078689
# Yolo County              -0.025118
# Yuba County               0.239264
# Name: violent, dtype: float64

# %%
# Compare property crime between 2020 and 2021
df_property = (y_2021['property']-y_2020['property'])/y_2020['property']
df_property.sort_values(ascending=False)
# Out:
# county
# Sierra County             1.941176
# Alpine County             0.642857
# Amador County             0.230241
# Merced County             0.224490
# Mariposa County           0.210000
# Madera County             0.172608
# San Francisco County      0.148770
# Trinity County            0.116162
# Butte County              0.101266
# San Diego County          0.100069
# San Luis Obispo County    0.094577
# Santa Barbara County      0.092330
# Humboldt County           0.092090
# Lassen County             0.070621
# Los Angeles County        0.067685
# Siskiyou County           0.061840
# Sacramento County         0.053166
# Inyo County               0.049844
# Kern County               0.047257
# Alameda County            0.046455
# Sonoma County             0.046007
# Fresno County             0.020360
# Stanislaus County         0.011344
# Placer County             0.001883
# Solano County             0.000573
# Tehama County            -0.003864
# Lake County              -0.009434
# San Joaquin County       -0.016288
# Tuolumne County          -0.016546
# San Benito County        -0.019197
# San Mateo County         -0.023327
# San Bernardino County    -0.023835
# Sutter County            -0.028866
# Tulare County            -0.033830
# Santa Clara County       -0.034041
# Orange County            -0.038761
# Colusa County            -0.045317
# Contra Costa County      -0.047901
# Riverside County         -0.050638
# Imperial County          -0.062352
# Ventura County           -0.070473
# Kings County             -0.072626
# Monterey County          -0.074275
# Plumas County            -0.085034
# Santa Cruz County        -0.092896
# El Dorado County         -0.094885
# Del Norte County         -0.105181
# Calaveras County         -0.116188
# Nevada County            -0.128180
# Mendocino County         -0.138810
# Yolo County              -0.143635
# Napa County              -0.164354
# Glenn County             -0.210762
# Marin County             -0.278020
# Modoc County             -0.282051
# Yuba County              -0.302553
# Mono County              -0.335404
# Shasta County            -0.889213
# Name: property, dtype: float64

# %%
y_2021
# Out:
#                         year   county_pop  violent  homicide  rape  robbery  \
# county
# Alameda County          2021    430685294    10510       146   671     4568
# Alpine County           2021        27170       19         0     2        0
# Amador County           2021      2921224      135         4     9       13
# Butte County            2021     22268520     1110        13   151      120
# Calaveras County        2021      2773140      185         2    35        4
# Colusa County           2021      1314780       55         0     8       12
# Contra Costa County     2021    347826102     3997        50   253     1003
# Del Norte County        2021       991908      230         1    44       33
# El Dorado County        2021     11615400      531         6    98       43
# Fresno County           2021    257299968     7405        87   406     1070
# Glenn County            2021      1375872      115         0    15        6
# Humboldt County         2021     16180320      670         8    91      141
# Imperial County         2021     19176005      546        13    24       86
# Inyo County             2021       908496      121         0    11       19
# Kern County             2021    175171392     6718       124   355     1249
# Kings County            2021     14504505      686        11    79       79
# Lake County             2021      3223448      367         4    48       40
# Lassen County           2021      1527024       80         0    13        6
# Los Angeles County      2021  11941011714    58104       838  3923    15619
# Madera County           2021      9534600     1022         5   118       55
# Marin County            2021     37319328      348         1    36      102
# Mariposa County         2021       410568       80         5    10        2
# Mendocino County        2021      6552216      473         8    53       33
# Merced County           2021     35272792     1833        27   101      228
# Modoc County            2021       411408       13         0     4        0
# Mono County             2021       477396       33         1     7        1
# Monterey County         2021     89198796     2035        35   186      381
# Napa County             2021     14710248      589         0    80       66
# Nevada County           2021      7448904      238         4    27       18
# Orange County           2021   1564697475     8126        71   895     1914
# Placer County           2021     38802166      740         4   103      126
# Plumas County           2021       717840      178         0    15        4
# Riverside County        2021    981271200     7201       111   531     1607
# Sacramento County       2021    304916352     7914       107   436     1798
# San Benito County       2021      3067050      292         1    39       34
# Ventura County                 1091     12161      1731           1204
# Yolo County                     459      5503       857            619
# Yuba County                     243      1284       242            293
#
#                         larceny_theft
# county
# Alameda County                  39598
# Alpine County                      14
# Amador County                     506
# Butte County                     3051
# Calaveras County                  385
# Colusa County                     189
# Contra Costa County             15437
# Del Norte County                  312
# El Dorado County                 1644
# Fresno County                   14177
# Glenn County                      205
# Humboldt County                  2180
# Imperial County                  1786
# Inyo County                       203
# Kern County                     14858
# Kings County                     1365
# Lake County                       521
# Lassen County                     211
# Los Angeles County             133309
# Madera County                    1569
# Marin County                     2816
# Mariposa County                   187
# Mendocino County                  726
# Merced County                    4430
# Modoc County                       30
# Mono County                        71
# Monterey County                  4489
# Napa County                      1397
# Nevada County                     514
# Orange County                   41058
# Placer County                    4256
# Plumas County                     166
# Riverside County                31365
# Sacramento County               22796
# San Benito County                 372
# San Bernardino County           23014
# San Diego County                34932
# San Francisco County            31861
# San Joaquin County              12070
# San Luis Obispo County           3667
# San Mateo County                10709
# Santa Barbara County             6055
# Santa Clara County              25671
# Santa Cruz County                3975
# Shasta County                     117
# Sierra County                      26
# Siskiyou County                   388
# Solano County                    6742
# Sonoma County                    4827
# Stanislaus County                7378
# Sutter County                    1542
# Tehama County                     730
# Trinity County                    112
# Tulare County                    5737
# Tuolumne County                   519
# Ventura County                   9226
# Yolo County                      4027
# Yuba County                       749

# %%
# Compare property crime between 2021 and 2022
df_property = (y_2022['property']-y_2022['property'])/y_2022['property']
df_property.sort_values(ascending=False)
# Out:
# county
# Alameda County            0.0
# Santa Cruz County         0.0
# Plumas County             0.0
# Riverside County          0.0
# Sacramento County         0.0
# San Benito County         0.0
# San Bernardino County     0.0
# San Diego County          0.0
# San Francisco County      0.0
# San Joaquin County        0.0
# San Luis Obispo County    0.0
# San Mateo County          0.0
# Santa Barbara County      0.0
# Santa Clara County        0.0
# Shasta County             0.0
# Alpine County             0.0
# Sierra County             0.0
# Siskiyou County           0.0
# Solano County             0.0
# Sonoma County             0.0
# Stanislaus County         0.0
# Sutter County             0.0
# Tehama County             0.0
# Trinity County            0.0
# Tulare County             0.0
# Tuolumne County           0.0
# Ventura County            0.0
# Yolo County               0.0
# Placer County             0.0
# Orange County             0.0
# Nevada County             0.0
# Napa County               0.0
# Amador County             0.0
# Butte County              0.0
# Calaveras County          0.0
# Colusa County             0.0
# Contra Costa County       0.0
# Del Norte County          0.0
# El Dorado County          0.0
# Fresno County             0.0
# Glenn County              0.0
# Humboldt County           0.0
# Imperial County           0.0
# Inyo County               0.0
# Kern County               0.0
# Kings County              0.0
# Lake County               0.0
# Lassen County             0.0
# Los Angeles County        0.0
# Madera County             0.0
# Marin County              0.0
# Mariposa County           0.0
# Mendocino County          0.0
# Merced County             0.0
# Modoc County              0.0
# Mono County               0.0
# Monterey County           0.0
# Yuba County               0.0
# Name: property, dtype: float64

# %%
df_violent = (y_2020['violent']-y_2019['violent'])/y_2019['violent']
df_violent.sort_values(ascending=False)
df_violent
# Out:
# county
# Alameda County           -0.006285
# Alpine County             0.461538
# Amador County             0.444444
# Butte County              0.043945
# Calaveras County          0.089655
# Colusa County             0.051724
# Contra Costa County      -0.063457
# Del Norte County          0.825688
# El Dorado County          0.137615
# Fresno County             0.253958
# Glenn County              0.670330
# Humboldt County           0.006390
# Imperial County          -0.011885
# Inyo County               0.351064
# Kern County               0.117383
# Kings County              0.023778
# Lake County               0.011527
# Lassen County            -0.219331
# Los Angeles County       -0.030925
# Madera County            -0.303614
# Marin County              0.207364
# Mariposa County          -0.227848
# Mendocino County          0.104167
# Merced County             0.076316
# Modoc County             -0.139535
# Mono County              -0.373134
# Monterey County           0.032798
# Napa County              -0.262654
# Nevada County            -0.058824
# Orange County             0.079758
# Placer County             0.079526
# Plumas County             0.242188
# Riverside County         -0.035681
# Sacramento County         0.081153
# San Benito County         0.115646
# San Bernardino County     0.048707
# San Diego County          0.009305
# San Francisco County     -0.192055
# San Joaquin County       -0.073085
# San Luis Obispo County    0.299363
# San Mateo County         -0.045182
# Santa Barbara County      0.192937
# Santa Clara County       -0.035057
# Santa Cruz County        -0.151899
# Shasta County             0.568218
# Sierra County             3.000000
# Siskiyou County           0.278409
# Solano County             0.106433
# Sonoma County             0.105447
# Stanislaus County        -0.029230
# Sutter County             0.057823
# Tehama County             0.355469
# Trinity County            0.344262
# Tulare County             0.004137
# Tuolumne County           0.251282
# Ventura County           -0.078689
# Yolo County              -0.025118
# Yuba County               0.239264
# Name: violent, dtype: float64

# %%
y_2019.loc['Shasta County']
# Out:
# year                 2019
# county_pop       11497280
# violent               623
# homicide                6
# rape                   63
# robbery                77
# agg_assault           477
# property             2413
# burglary              630
# vehicle_theft         581
# larceny_theft        1202
# Name: Shasta County, dtype: int64

# %%
y_2020.loc['Shasta County']
# Out:
# year                 2020
# county_pop       12889944
# violent               977
# homicide               12
# rape                   99
# robbery               126
# agg_assault           740
# property             3430
# burglary              936
# vehicle_theft         466
# larceny_theft        2028
# Name: Shasta County, dtype: int64

# %%
# Create a list of County names
county_names = y_19["county"].unique()
county_names_list = list(county_names)

# %%
crime_columns = list(y_19.columns)
# item_list = [e for e in item_list if e not in ('item', 5)]
crime_columns_list = [i for i in crime_columns if i not in ('year', 'county', 'month', 'county_pop')]
crime_columns_list

# %%
crime_in_county =

# %%
# Create A loop to extarct specific data
county_19 = [county_names_list]
#crime_19 = 
for i, row in y_19.iterrows():
    if robbery in county_19[3]
    print()

# %%
march_count_19 = y_19.loc[(y_19["county"] == 'Alameda County') & (y_19["month"] == 'March')].sum()
march_count_19

# %%
newdf_2019 = newdf.groupby(['year', 'month']).sum()
newdf_2019.head(5)

# %%
newdf1 = newdf_2019["year"].unique()
year_n = pd.to_datetime(newdf1, format='%y').strftime('%B')

#year_n

# year_n1 = list(year_n)

#year_19 = newdf['year'].unique('2019')
# year_20 = newdf['year'].unique()
# year_21 = newdf['year'].unique()
# year_22 = newdf['year'].unique()

print(len(year_n))
# print(len(year_20))
# print(len(year_21))
# print(len(year_22))

# %%
county_pop = newdf['county_pop'].unique()
county_count = newdf['county'].unique()
# y_2019 = newdf.groupby(['year', 'month']).sum()
# newdf_2019
print(len(county_pop))
print(len(county_count))
